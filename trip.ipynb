# %%
#Импорт библиотек
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import animation
from matplotlib import pyplot as plt

# %%
smt0 = 10e-4
smtk = 10e-6
Isp = 4500
g0 = 9.8791
MassWet = 8200
MassDry = 1050
Thrust = 0.15

# %%
Radius = [] # Радиус вектор положения КА
Ro_k = [] # Радиус вектор положения планеты назначения
mu0 = # гравипараметр планеты 
muK = # гравипараметр планеты назначения
muKD = muK / mu0 # грависфера

# %%
k = 1 - Tau
